# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
set_count = 1
record_count = 1
print('Beginning Data Retrieval')
print('--'*25)
City=[]
Cloudiness=[]
Country=[]
Date=[]
Humidity=[]
Lat=[]
Lng=[]
Maxtemp=[]
Winspeed=[]
for i in cities:
    urls = url + "appid=" + api_key + "&q=" + i +"&units=" + units
    response=requests.get(urls).json()
    try:
        if record_count<=50:
            print('Processing Record '+ str(record_count)+' of Set '+str(set_count)+'|'+i)
            record_count+=1
            City.append(response['name'])
            Cloudiness.append(response['clouds']['all'])
            Country.append(response['sys']['country'])
            Date.append(response['dt'])
            Humidity.append(response['main']['humidity'])
            Lat.append(response['coord']['lat'])
            Lng.append(response['coord']['lon'])
            Maxtemp.append(response['main']['temp_max'])
            Winspeed.append(response['wind']['speed'])
        else:
            record_count=0
            set_count+=1
            print('Processing Record '+ str(record_count)+' of Set '+str(set_count)+'|'+i)
            record_count += 1
    except KeyError:
        print("City not found. Skipping...")
# Out:
# Beginning Data Retrieval
# --------------------------------------------------
# Processing Record 1 of Set 1|hasaki
# Processing Record 2 of Set 1|chavantes
# Processing Record 3 of Set 1|haines junction
# Processing Record 4 of Set 1|cherskiy
# Processing Record 5 of Set 1|port elizabeth
# Processing Record 6 of Set 1|ixtapa
# Processing Record 7 of Set 1|cape town
# Processing Record 8 of Set 1|barrow
# Processing Record 9 of Set 1|bluff
# Processing Record 10 of Set 1|ushuaia
# Processing Record 11 of Set 1|passo de camaragibe
# Processing Record 12 of Set 1|tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 1|rikitea
# Processing Record 14 of Set 1|punta arenas
# Processing Record 15 of Set 1|kavaratti
# Processing Record 16 of Set 1|shenjiamen
# Processing Record 17 of Set 1|hermanus
# Processing Record 18 of Set 1|tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 1|busselton
# Processing Record 20 of Set 1|haibowan
# City not found. Skipping...
# Processing Record 21 of Set 1|shitanjing
# Processing Record 22 of Set 1|juneau
# Processing Record 23 of Set 1|port alfred
# Processing Record 24 of Set 1|saint-philippe
# Processing Record 25 of Set 1|hellvik
# Processing Record 26 of Set 1|butaritari
# Processing Record 27 of Set 1|alibag
# Processing Record 28 of Set 1|airai
# Processing Record 29 of Set 1|asau
# City not found. Skipping...
# Processing Record 30 of Set 1|tuktoyaktuk
# Processing Record 31 of Set 1|vaini
# Processing Record 32 of Set 1|leh
# Processing Record 33 of Set 1|kosh-agach
# Processing Record 34 of Set 1|nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 1|puerto ayora
# Processing Record 36 of Set 1|pacifica
# Processing Record 37 of Set 1|upernavik
# Processing Record 38 of Set 1|east london
# Processing Record 39 of Set 1|bredasdorp
# Processing Record 40 of Set 1|saleaula
# City not found. Skipping...
# Processing Record 41 of Set 1|albany
# Processing Record 42 of Set 1|amderma
# City not found. Skipping...
# Processing Record 43 of Set 1|miri
# Processing Record 44 of Set 1|nioro
# Processing Record 45 of Set 1|yellowknife
# Processing Record 46 of Set 1|fortuna
# Processing Record 47 of Set 1|flinders
# Processing Record 48 of Set 1|iracoubo
# Processing Record 49 of Set 1|carnarvon
# Processing Record 50 of Set 1|lolua
# City not found. Skipping...
# Processing Record 0 of Set 2|mataura
# Processing Record 1 of Set 2|victoria
# Processing Record 2 of Set 2|tuatapere
# Processing Record 3 of Set 2|dwarka
# Processing Record 4 of Set 2|illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 2|hithadhoo
# Processing Record 6 of Set 2|sandur
# Processing Record 7 of Set 2|elizabeth city
# Processing Record 8 of Set 2|chuy
# Processing Record 9 of Set 2|chokurdakh
# Processing Record 10 of Set 2|belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 2|lavrentiya
# Processing Record 12 of Set 2|salalah
# Processing Record 13 of Set 2|nalut
# Processing Record 14 of Set 2|provideniya
# Processing Record 15 of Set 2|kapaa
# Processing Record 16 of Set 2|namie
# Processing Record 17 of Set 2|vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 2|eufaula
# Processing Record 19 of Set 2|bom jardim
# Processing Record 20 of Set 2|saskylakh
# Processing Record 21 of Set 2|ribeira grande
# Processing Record 22 of Set 2|port lincoln
# Processing Record 23 of Set 2|navirai
# Processing Record 24 of Set 2|touros
# Processing Record 25 of Set 2|nikolskoye
# Processing Record 26 of Set 2|rzhev
# Processing Record 27 of Set 2|karaul
# City not found. Skipping...
# Processing Record 28 of Set 2|ailigandi
# Processing Record 29 of Set 2|anloga
# Processing Record 30 of Set 2|tianpeng
# Processing Record 31 of Set 2|misratah
# Processing Record 32 of Set 2|panacan
# Processing Record 33 of Set 2|geraldton
# Processing Record 34 of Set 2|bambous virieux
# Processing Record 35 of Set 2|sao felix do xingu
# Processing Record 36 of Set 2|atuona
# Processing Record 37 of Set 2|padang
# Processing Record 38 of Set 2|zabol
# Processing Record 39 of Set 2|puerto cortes
# City not found. Skipping...
# Processing Record 40 of Set 2|ilulissat
# Processing Record 41 of Set 2|birjand
# Processing Record 42 of Set 2|ponta do sol
# Processing Record 43 of Set 2|wote
# Processing Record 44 of Set 2|longyearbyen
# Processing Record 45 of Set 2|vardo
# Processing Record 46 of Set 2|tasiilaq
# Processing Record 47 of Set 2|new norfolk
# Processing Record 48 of Set 2|coihaique
# Processing Record 49 of Set 2|wajima
# Processing Record 50 of Set 2|along
# Processing Record 0 of Set 3|sentyabrskiy
# Processing Record 1 of Set 3|oyama
# Processing Record 2 of Set 3|hilton head island
# Processing Record 3 of Set 3|shar
# Processing Record 4 of Set 3|bajitpur
# Processing Record 5 of Set 3|taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 3|koygorodok
# Processing Record 7 of Set 3|mitsamiouli
# Processing Record 8 of Set 3|cooma
# Processing Record 9 of Set 3|blackwater
# Processing Record 10 of Set 3|yulara
# Processing Record 11 of Set 3|wanning
# Processing Record 12 of Set 3|lebu
# Processing Record 13 of Set 3|kruisfontein
# Processing Record 14 of Set 3|tomatlan
# Processing Record 15 of Set 3|tual
# Processing Record 16 of Set 3|torrington
# Processing Record 17 of Set 3|souillac
# Processing Record 18 of Set 3|jamestown
# Processing Record 19 of Set 3|taoudenni
# Processing Record 20 of Set 3|hofn
# Processing Record 21 of Set 3|yar-sale
# Processing Record 22 of Set 3|castro
# Processing Record 23 of Set 3|kavieng
# Processing Record 24 of Set 3|coquimbo
# Processing Record 25 of Set 3|marsh harbour
# Processing Record 26 of Set 3|severo-kurilsk
# Processing Record 27 of Set 3|havelock
# Processing Record 28 of Set 3|kijang
# Processing Record 29 of Set 3|bandarbeyla
# Processing Record 30 of Set 3|kodiak
# Processing Record 31 of Set 3|killybegs
# Processing Record 32 of Set 3|aklavik
# Processing Record 33 of Set 3|hambantota
# Processing Record 34 of Set 3|we
# City not found. Skipping...
# Processing Record 35 of Set 3|lubango
# Processing Record 36 of Set 3|kahului
# Processing Record 37 of Set 3|port augusta
# Processing Record 38 of Set 3|santa maria
# Processing Record 39 of Set 3|arraial do cabo
# Processing Record 40 of Set 3|villarrica
# Processing Record 41 of Set 3|gamba
# Processing Record 42 of Set 3|khatanga
# Processing Record 43 of Set 3|watertown
# Processing Record 44 of Set 3|zhigansk
# Processing Record 45 of Set 3|eureka
# Processing Record 46 of Set 3|ucluelet
# Processing Record 47 of Set 3|lompoc
# Processing Record 48 of Set 3|egvekinot
# Processing Record 49 of Set 3|atar
# Processing Record 50 of Set 3|adrar
# Processing Record 0 of Set 4|ginda
# Processing Record 1 of Set 4|half moon bay
# Processing Record 2 of Set 4|xining
# Processing Record 3 of Set 4|darnah
# Processing Record 4 of Set 4|januaria
# City not found. Skipping...
# Processing Record 5 of Set 4|mogadishu
# Processing Record 6 of Set 4|hilo
# Processing Record 7 of Set 4|qaanaaq
# Processing Record 8 of Set 4|puro
# Processing Record 9 of Set 4|tambo
# Processing Record 10 of Set 4|pevek
# Processing Record 11 of Set 4|grand gaube
# Processing Record 12 of Set 4|palasa
# City not found. Skipping...
# Processing Record 13 of Set 4|avera
# Processing Record 14 of Set 4|najran
# Processing Record 15 of Set 4|sotouboua
# Processing Record 16 of Set 4|mount gambier
# Processing Record 17 of Set 4|ha giang
# Processing Record 18 of Set 4|hobart
# Processing Record 19 of Set 4|puerto baquerizo moreno
# Processing Record 20 of Set 4|norman wells
# Processing Record 21 of Set 4|neepawa
# Processing Record 22 of Set 4|parrita
# Processing Record 23 of Set 4|vostok
# Processing Record 24 of Set 4|san matias
# Processing Record 25 of Set 4|lagoa
# Processing Record 26 of Set 4|chardara
# City not found. Skipping...
# Processing Record 27 of Set 4|maryville
# Processing Record 28 of Set 4|manggar
# Processing Record 29 of Set 4|auki
# Processing Record 30 of Set 4|paamiut
# Processing Record 31 of Set 4|manaus
# Processing Record 32 of Set 4|litoral del san juan
# City not found. Skipping...
# Processing Record 33 of Set 4|katsuura
# Processing Record 34 of Set 4|marawi
# Processing Record 35 of Set 4|pacific grove
# Processing Record 36 of Set 4|clyde river
# Processing Record 37 of Set 4|sayyan
# Processing Record 38 of Set 4|sisimiut
# Processing Record 39 of Set 4|attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 4|gornopravdinsk
# Processing Record 41 of Set 4|linguere
# City not found. Skipping...
# Processing Record 42 of Set 4|dobarlau
# Processing Record 43 of Set 4|port macquarie
# Processing Record 44 of Set 4|ostrovnoy
# Processing Record 45 of Set 4|puri
# Processing Record 46 of Set 4|scarborough
# Processing Record 47 of Set 4|georgetown
# Processing Record 48 of Set 4|vila velha
# Processing Record 49 of Set 4|utiroa
# City not found. Skipping...
# Processing Record 50 of Set 4|iralaya
# Processing Record 0 of Set 5|mbala
# Processing Record 1 of Set 5|pangnirtung
# Processing Record 2 of Set 5|saint george
# Processing Record 3 of Set 5|tutoia
# Processing Record 4 of Set 5|namibe
# Processing Record 5 of Set 5|thompson
# Processing Record 6 of Set 5|mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 5|alexandria
# Processing Record 8 of Set 5|santa vitoria do palmar
# Processing Record 9 of Set 5|sorvag
# City not found. Skipping...
# Processing Record 10 of Set 5|tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 5|madang
# Processing Record 12 of Set 5|athabasca
# Processing Record 13 of Set 5|avarua
# Processing Record 14 of Set 5|margate
# Processing Record 15 of Set 5|namatanai
# Processing Record 16 of Set 5|baraya
# Processing Record 17 of Set 5|tigil
# Processing Record 18 of Set 5|isangel
# Processing Record 19 of Set 5|coahuayana
# Processing Record 20 of Set 5|middelburg
# Processing Record 21 of Set 5|matara
# Processing Record 22 of Set 5|leshukonskoye
# Processing Record 23 of Set 5|saldanha
# Processing Record 24 of Set 5|narsaq
# Processing Record 25 of Set 5|comodoro rivadavia
# Processing Record 26 of Set 5|lasa
# Processing Record 27 of Set 5|anadyr
# Processing Record 28 of Set 5|limoges
# Processing Record 29 of Set 5|umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 5|ancud
# Processing Record 31 of Set 5|baruun-urt
# Processing Record 32 of Set 5|labuhan
# Processing Record 33 of Set 5|sambava
# Processing Record 34 of Set 5|pouembout
# Processing Record 35 of Set 5|leningradskiy
# Processing Record 36 of Set 5|barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 5|katherine
# Processing Record 38 of Set 5|asfi
# City not found. Skipping...
# Processing Record 39 of Set 5|codrington
# Processing Record 40 of Set 5|hirara
# Processing Record 41 of Set 5|sept-iles
# Processing Record 42 of Set 5|chapais
# Processing Record 43 of Set 5|tiksi
# Processing Record 44 of Set 5|ushtobe
# Processing Record 45 of Set 5|esmeraldas
# Processing Record 46 of Set 5|rishikesh
# Processing Record 47 of Set 5|bathsheba
# Processing Record 48 of Set 5|college
# Processing Record 49 of Set 5|barranca
# Processing Record 50 of Set 5|makakilo city
# Processing Record 0 of Set 6|gorontalo
# Processing Record 1 of Set 6|kieta
# Processing Record 2 of Set 6|awbari
# Processing Record 3 of Set 6|karabulak
# Processing Record 4 of Set 6|sangar
# Processing Record 5 of Set 6|agua blanca
# Processing Record 6 of Set 6|saint-georges
# Processing Record 7 of Set 6|sabancuy
# Processing Record 8 of Set 6|kirkwall
# Processing Record 9 of Set 6|la ronge
# Processing Record 10 of Set 6|boa vista
# Processing Record 11 of Set 6|talnakh
# Processing Record 12 of Set 6|fougeres
# Processing Record 13 of Set 6|butler
# Processing Record 14 of Set 6|faanui
# Processing Record 15 of Set 6|rosignol
# Processing Record 16 of Set 6|ribeirao branco
# Processing Record 17 of Set 6|hukuntsi
# Processing Record 18 of Set 6|mayor pablo lagerenza
# Processing Record 19 of Set 6|lagos
# Processing Record 20 of Set 6|mount pleasant
# Processing Record 21 of Set 6|kuruman
# Processing Record 22 of Set 6|camocim
# Processing Record 23 of Set 6|gladstone
# Processing Record 24 of Set 6|waitakere
# Processing Record 25 of Set 6|sechura
# Processing Record 26 of Set 6|tadine
# Processing Record 27 of Set 6|salta
# Processing Record 28 of Set 6|okha
# Processing Record 29 of Set 6|lethem
# Processing Record 30 of Set 6|bilma
# Processing Record 31 of Set 6|marienburg
# Processing Record 32 of Set 6|bad hersfeld
# Processing Record 33 of Set 6|hamilton
# Processing Record 34 of Set 6|zabaykalsk
# Processing Record 35 of Set 6|satitoa
# City not found. Skipping...
# Processing Record 36 of Set 6|menongue
# Processing Record 37 of Set 6|saint-pierre
# Processing Record 38 of Set 6|marcona
# City not found. Skipping...
# Processing Record 39 of Set 6|cabo san lucas
# Processing Record 40 of Set 6|healdsburg
# Processing Record 41 of Set 6|pangody
# Processing Record 42 of Set 6|bolshevik
# Processing Record 43 of Set 6|micomeseng
# Processing Record 44 of Set 6|belyy yar
# Processing Record 45 of Set 6|raudeberg
# Processing Record 46 of Set 6|arman
# Processing Record 47 of Set 6|beringovskiy
# Processing Record 48 of Set 6|minot
# Processing Record 49 of Set 6|kiunga
# Processing Record 50 of Set 6|petropavlovsk-kamchatskiy
# Processing Record 0 of Set 7|suruc
# Processing Record 1 of Set 7|luganville
# Processing Record 2 of Set 7|tessalit
# Processing Record 3 of Set 7|sao filipe
# Processing Record 4 of Set 7|pisco
# Processing Record 5 of Set 7|kamenskiy
# Processing Record 6 of Set 7|anton lizardo
# Processing Record 7 of Set 7|esperance
# Processing Record 8 of Set 7|arrecife
# City not found. Skipping...
# Processing Record 9 of Set 7|nabire
# Processing Record 10 of Set 7|ryotsu
# Processing Record 11 of Set 7|saint-pierre-des-corps
# Processing Record 12 of Set 7|louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 7|islampur
# Processing Record 14 of Set 7|muisne
# Processing Record 15 of Set 7|faya
# Processing Record 16 of Set 7|bata
# Processing Record 17 of Set 7|coswig
# Processing Record 18 of Set 7|nguruka
# Processing Record 19 of Set 7|paita
# Processing Record 20 of Set 7|stralsund
# Processing Record 21 of Set 7|odweyne
# City not found. Skipping...
# Processing Record 22 of Set 7|san cristobal
# Processing Record 23 of Set 7|dingle
# Processing Record 24 of Set 7|porto de moz
# Processing Record 25 of Set 7|sitka
# Processing Record 26 of Set 7|san patricio
# Processing Record 27 of Set 7|kharp
# Processing Record 28 of Set 7|chumikan
# Processing Record 29 of Set 7|meulaboh
# Processing Record 30 of Set 7|goderich
# Processing Record 31 of Set 7|vagur
# Processing Record 32 of Set 7|dikson
# Processing Record 33 of Set 7|drayton valley
# Processing Record 34 of Set 7|boyolangu
# Processing Record 35 of Set 7|castellammare del golfo
# Processing Record 36 of Set 7|lajkovac
# Processing Record 37 of Set 7|mar del plata
# Processing Record 38 of Set 7|milkovo
# Processing Record 39 of Set 7|sibolga
# Processing Record 40 of Set 7|the valley
# Processing Record 41 of Set 7|almunecar
# Processing Record 42 of Set 7|buchanan
# Processing Record 43 of Set 7|feijo
# Processing Record 44 of Set 7|sao joao da barra
# Processing Record 45 of Set 7|bayir
# Processing Record 46 of Set 7|dillon
# Processing Record 47 of Set 7|brae
# Processing Record 48 of Set 7|itaporanga
# Processing Record 49 of Set 7|mahebourg
# Processing Record 50 of Set 7|namwala
# Processing Record 0 of Set 8|colac
# Processing Record 1 of Set 8|alice springs
# Processing Record 2 of Set 8|micheweni
# Processing Record 3 of Set 8|laguna
# Processing Record 4 of Set 8|saltpond
# Processing Record 5 of Set 8|utete
# Processing Record 6 of Set 8|acapulco
# Processing Record 7 of Set 8|waipawa
# Processing Record 8 of Set 8|te anau
# Processing Record 9 of Set 8|houma
# Processing Record 10 of Set 8|brainerd
# Processing Record 11 of Set 8|manaure
# Processing Record 12 of Set 8|teguise
# Processing Record 13 of Set 8|havoysund
# Processing Record 14 of Set 8|turukhansk
# Processing Record 15 of Set 8|tiarei
# Processing Record 16 of Set 8|luderitz
# Processing Record 17 of Set 8|ambulu
# Processing Record 18 of Set 8|saint anthony
# Processing Record 19 of Set 8|kupang
# Processing Record 20 of Set 8|saint-joseph
# Processing Record 21 of Set 8|itarema
# Processing Record 22 of Set 8|sorland
# Processing Record 23 of Set 8|bambanglipuro
# Processing Record 24 of Set 8|iqaluit
# Processing Record 25 of Set 8|quetigny
# Processing Record 26 of Set 8|lata
# Processing Record 27 of Set 8|tungawan
# Processing Record 28 of Set 8|zhezkazgan
# Processing Record 29 of Set 8|lhokseumawe
# Processing Record 30 of Set 8|grindavik
# Processing Record 31 of Set 8|san francisco de cones
# Processing Record 32 of Set 8|bocas del toro
# Processing Record 33 of Set 8|muncar
# Processing Record 34 of Set 8|machinga
# Processing Record 35 of Set 8|mount isa
# Processing Record 36 of Set 8|camana
# City not found. Skipping...
# Processing Record 37 of Set 8|ust-kamchatsk
# City not found. Skipping...
# Processing Record 38 of Set 8|andilamena
# Processing Record 39 of Set 8|husavik
# Processing Record 40 of Set 8|olafsvik
# City not found. Skipping...
# Processing Record 41 of Set 8|praia
# Processing Record 42 of Set 8|nanortalik
# Processing Record 43 of Set 8|kogon
# Processing Record 44 of Set 8|vengerovo
# Processing Record 45 of Set 8|constitucion
# Processing Record 46 of Set 8|buraydah
# Processing Record 47 of Set 8|hirado
# Processing Record 48 of Set 8|aksarka
# Processing Record 49 of Set 8|fort nelson
# Processing Record 50 of Set 8|aquiraz
# Processing Record 0 of Set 9|bethel
# Processing Record 1 of Set 9|linhares
# Processing Record 2 of Set 9|guajara-mirim
# City not found. Skipping...
# Processing Record 3 of Set 9|roma
# Processing Record 4 of Set 9|lazaro cardenas
# Processing Record 5 of Set 9|kutum
# Processing Record 6 of Set 9|praia da vitoria
# Processing Record 7 of Set 9|altay
# Processing Record 8 of Set 9|grand centre
# City not found. Skipping...
# Processing Record 9 of Set 9|mogwase
# Processing Record 10 of Set 9|vero beach
# Processing Record 11 of Set 9|ulladulla
# Processing Record 12 of Set 9|bulgan
# Processing Record 13 of Set 9|cayenne
# Processing Record 14 of Set 9|san andres
# Processing Record 15 of Set 9|biak
# Processing Record 16 of Set 9|chirilagua
# Processing Record 17 of Set 9|solsvik
# City not found. Skipping...
# Processing Record 18 of Set 9|le port
# Processing Record 19 of Set 9|umm kaddadah
# Processing Record 20 of Set 9|avesta
# Processing Record 21 of Set 9|shepsi
# Processing Record 22 of Set 9|dundalk
# Processing Record 23 of Set 9|vao
# Processing Record 24 of Set 9|tautira
# Processing Record 25 of Set 9|dangriga
# Processing Record 26 of Set 9|nguiu
# City not found. Skipping...
# Processing Record 27 of Set 9|kaeo
# Processing Record 28 of Set 9|jiangyou
# Processing Record 29 of Set 9|saint-nazaire
# Processing Record 30 of Set 9|ipixuna
# Processing Record 31 of Set 9|klaksvik
# Processing Record 32 of Set 9|banjar
# Processing Record 33 of Set 9|vila
# Processing Record 34 of Set 9|manta
# Processing Record 35 of Set 9|desaguadero
# Processing Record 36 of Set 9|torbay
# Processing Record 37 of Set 9|balabac
# Processing Record 38 of Set 9|grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 9|sola
# Processing Record 40 of Set 9|whitehorse
# Processing Record 41 of Set 9|saint marys
# Processing Record 42 of Set 9|ituni
# City not found. Skipping...
# Processing Record 43 of Set 9|rawannawi
# City not found. Skipping...
# Processing Record 44 of Set 9|rungata
# City not found. Skipping...
# Processing Record 45 of Set 9|abnub
# Processing Record 46 of Set 9|berkovica
# Processing Record 47 of Set 9|albacete
# Processing Record 48 of Set 9|zhangye
# Processing Record 49 of Set 9|maykain
# City not found. Skipping...
# Processing Record 50 of Set 9|carballo
# Processing Record 0 of Set 10|ipameri
# Processing Record 1 of Set 10|port-cartier
# Processing Record 2 of Set 10|shimoda
# Processing Record 3 of Set 10|mendahara
# City not found. Skipping...
# Processing Record 4 of Set 10|weinan
# Processing Record 5 of Set 10|meadow lake
# Processing Record 6 of Set 10|muhos
# Processing Record 7 of Set 10|songjianghe
# Processing Record 8 of Set 10|carutapera
# Processing Record 9 of Set 10|xuddur
# Processing Record 10 of Set 10|bethanien
# Processing Record 11 of Set 10|vetluzhskiy
# Processing Record 12 of Set 10|gondar
# Processing Record 13 of Set 10|port hedland
# Processing Record 14 of Set 10|pocatello
# Processing Record 15 of Set 10|toora-khem
# Processing Record 16 of Set 10|deep river
# Processing Record 17 of Set 10|maniitsoq
# Processing Record 18 of Set 10|bengkulu
# City not found. Skipping...
# Processing Record 19 of Set 10|dunedin
# Processing Record 20 of Set 10|rio bueno
# Processing Record 21 of Set 10|dubbo
# Processing Record 22 of Set 10|alta floresta
# Processing Record 23 of Set 10|evensk
# Processing Record 24 of Set 10|sovetskiy
# Processing Record 25 of Set 10|rabo de peixe
# Processing Record 26 of Set 10|amarpur
# Processing Record 27 of Set 10|poronaysk
# Processing Record 28 of Set 10|hovd
# Processing Record 29 of Set 10|giddalur
# Processing Record 30 of Set 10|msanga
# Processing Record 31 of Set 10|porto velho
# Processing Record 32 of Set 10|katangli
# Processing Record 33 of Set 10|natal
# Processing Record 34 of Set 10|pringsewu
# Processing Record 35 of Set 10|mastic beach
# Processing Record 36 of Set 10|abu kamal
# Processing Record 37 of Set 10|high level
# Processing Record 38 of Set 10|verkhnevilyuysk
# Processing Record 39 of Set 10|vorontsovka
# Processing Record 40 of Set 10|kaliua
# Processing Record 41 of Set 10|camacha
# Processing Record 42 of Set 10|warqla
# City not found. Skipping...
# Processing Record 43 of Set 10|tongchuan
# Processing Record 44 of Set 10|palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 10|kodama
# Processing Record 46 of Set 10|takoradi
# Processing Record 47 of Set 10|navoi
# Processing Record 48 of Set 10|ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 49 of Set 10|balotra
# Processing Record 50 of Set 10|san quintin
# Processing Record 0 of Set 11|isiro
# Processing Record 1 of Set 11|birao
# Processing Record 2 of Set 11|mantua
# Processing Record 3 of Set 11|kazalinsk
# City not found. Skipping...
# Processing Record 4 of Set 11|sarakhs
# Processing Record 5 of Set 11|betanzos
# Processing Record 6 of Set 11|vestmannaeyjar
# Processing Record 7 of Set 11|port-gentil
# Processing Record 8 of Set 11|arawa
# Processing Record 9 of Set 11|jinchang
# Processing Record 10 of Set 11|oranjemund
# Processing Record 11 of Set 11|hay river
# Processing Record 12 of Set 11|khonuu
# City not found. Skipping...
# Processing Record 13 of Set 11|riyadh
# Processing Record 14 of Set 11|tema
# Processing Record 15 of Set 11|wlodawa
# Processing Record 16 of Set 11|muli
# Processing Record 17 of Set 11|portobelo
# Processing Record 18 of Set 11|havre
# Processing Record 19 of Set 11|ondjiva
# Processing Record 20 of Set 11|bourail
# Processing Record 21 of Set 11|bokovskaya
# Processing Record 22 of Set 11|kenosha
# Processing Record 23 of Set 11|bijar
# Processing Record 24 of Set 11|ust-omchug
# Processing Record 25 of Set 11|santo tomas
# Processing Record 26 of Set 11|norsup
# Processing Record 27 of Set 11|limbang
# Processing Record 28 of Set 11|cap malheureux
# Processing Record 29 of Set 11|oblivskaya
# Processing Record 30 of Set 11|bagdarin
# Processing Record 31 of Set 11|ayabaca
# Processing Record 32 of Set 11|denpasar
# Processing Record 33 of Set 11|carapegua
# Processing Record 34 of Set 11|ksenyevka
# City not found. Skipping...
# Processing Record 35 of Set 11|khandyga
# Processing Record 36 of Set 11|rudnyy
# Processing Record 37 of Set 11|pimentel
# Processing Record 38 of Set 11|umm durman
# City not found. Skipping...
# Processing Record 39 of Set 11|kaabong
# Processing Record 40 of Set 11|stettler
# Processing Record 41 of Set 11|pingliang
# Processing Record 42 of Set 11|kuli
# Processing Record 43 of Set 11|hobyo
# Processing Record 44 of Set 11|honiara
# Processing Record 45 of Set 11|nome
# Processing Record 46 of Set 11|durango
# Processing Record 47 of Set 11|samarai
# Processing Record 48 of Set 11|muros
# Processing Record 49 of Set 11|lithakia
# Processing Record 50 of Set 11|roura
# Processing Record 0 of Set 12|chute-aux-outardes
# Processing Record 1 of Set 12|puerto carreno
# Processing Record 2 of Set 12|maidens
# Processing Record 3 of Set 12|asyut
# Processing Record 4 of Set 12|iberia
# Processing Record 5 of Set 12|manzil jamil
# City not found. Skipping...
# Processing Record 6 of Set 12|panalingaan
# Processing Record 7 of Set 12|port huron
# Processing Record 8 of Set 12|nova venecia
# Processing Record 9 of Set 12|westport
# Processing Record 10 of Set 12|port hawkesbury
# Processing Record 11 of Set 12|doljo
# Processing Record 12 of Set 12|sukumo
# Processing Record 13 of Set 12|valparaiso
# Processing Record 14 of Set 12|ahuimanu
# Processing Record 15 of Set 12|banyuwangi
# Processing Record 16 of Set 12|kaitangata
# Processing Record 17 of Set 12|broken hill
# Processing Record 18 of Set 12|ranong
# Processing Record 19 of Set 12|porto novo
# Processing Record 20 of Set 12|waitati
# Processing Record 21 of Set 12|ambon
# Processing Record 22 of Set 12|ayan
# Processing Record 23 of Set 12|bara
# Processing Record 24 of Set 12|eyl
# Processing Record 25 of Set 12|temaraia
# City not found. Skipping...
# Processing Record 26 of Set 12|acarau
# City not found. Skipping...
# Processing Record 27 of Set 12|solnechnyy
# Processing Record 28 of Set 12|fairbanks
# Processing Record 29 of Set 12|caravelas
# Processing Record 30 of Set 12|noshiro
# Processing Record 31 of Set 12|vieux fort
# Processing Record 32 of Set 12|alta
# Processing Record 33 of Set 12|pula
# Processing Record 34 of Set 12|bacalar
# Processing Record 35 of Set 12|les cayes
# Processing Record 36 of Set 12|galesong
# Processing Record 37 of Set 12|kapuskasing
# Processing Record 38 of Set 12|grenville
# Processing Record 39 of Set 12|sobolevo
# Processing Record 40 of Set 12|itaituba
# Processing Record 41 of Set 12|mlonggo
# Processing Record 42 of Set 12|kaniv
# Processing Record 43 of Set 12|kysyl-syr
# Processing Record 44 of Set 12|urengoy
# Processing Record 45 of Set 12|iskateley
# Processing Record 46 of Set 12|samusu
# City not found. Skipping...
# Processing Record 47 of Set 12|port moresby
# Processing Record 48 of Set 12|berlevag
# Processing Record 49 of Set 12|ortona
# Processing Record 50 of Set 12|smithers
# Processing Record 0 of Set 13|atasu
# Processing Record 1 of Set 13|port hardy
# Processing Record 2 of Set 13|sechelt
# Processing Record 3 of Set 13|tecoanapa
# Processing Record 4 of Set 13|molokovo
# Processing Record 5 of Set 13|salinopolis
# Processing Record 6 of Set 13|macapa
# Processing Record 7 of Set 13|tevaitoa
# Processing Record 8 of Set 13|antofagasta
# Processing Record 9 of Set 13|yatou
# Processing Record 10 of Set 13|kachiry
# Processing Record 11 of Set 13|flagstaff
# Processing Record 12 of Set 13|kargil

# %%
for i in cities:
    urls = url + "appid=" + api_key + "&q=" + i +"&units=" + units
    response=requests.get(urls).json()
    pprint(response)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 35.73, 'lon': 140.83},
#  'dt': 1573484680,
#  'id': 2112802,
#  'main': {'humidity': 93,
#           'pressure': 1006,
#           'temp': 48.6,
#           'temp_max': 51.8,
#           'temp_min': 46.4},
#  'name': 'Hasaki',
#  'sys': {'country': 'JP',
#          'id': 7955,
#          'sunrise': 1573506532,
#          'sunset': 1573543964,
#          'type': 1},
#  'timezone': 32400,
#  'visibility': 4000,
#  'weather': [{'description': 'mist', 'icon': '50n', 'id': 701, 'main': 'Mist'},
#              {'description': 'fog', 'icon': '50n', 'id': 741, 'main': 'Fog'}],
#  'wind': {'deg': 310, 'speed': 3.36}}
# {'base': 'model',
#  'clouds': {'all': 85},
#  'cod': 200,
#  'coord': {'lat': -23.04, 'lon': -49.71},
#  'dt': 1573484866,
#  'id': 3444843,
#  'main': {'grnd_level': 947,
#           'humidity': 73,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 79.77,
#           'temp_max': 79.77,
#           'temp_min': 79.77},
#  'name': 'Chavantes',
#  'rain': {'3h': 1.38},
#  'sys': {'country': 'BR', 'sunrise': 1573460909, 'sunset': 1573508239},
#  'timezone': -10800,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 112, 'speed': 9.04}}
# {'base': 'model',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': 60.75, 'lon': -137.51},
#  'dt': 1573484866,
#  'id': 5969025,
#  'main': {'grnd_level': 879,
#           'humidity': 71,
#           'pressure': 1020,
#           'sea_level': 1020,
#           'temp': 5.97,
#           'temp_max': 5.97,
#           'temp_min': 5.97},
#  'name': 'Haines Junction',
#  'sys': {'country': 'CA', 'sunrise': 1573491729, 'sunset': 1573519566},
#  'timezone': -28800,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 30, 'speed': 4.12}}
# {'base': 'model',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 68.75, 'lon': 161.3},
#  'dt': 1573484866,
#  'id': 2126199,
#  'main': {'grnd_level': 1009,
#           'humidity': 70,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 26.44,
#           'temp_max': 26.44,
#           'temp_min': 26.44},
#  'name': 'Cherskiy',
#  'sys': {'country': 'RU', 'sunrise': 1573510786, 'sunset': 1573529884},
#  'timezone': 39600,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 349, 'speed': 4.21}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 39.31, 'lon': -74.98},
#  'dt': 1573484866,
#  'id': 4501427,
#  'main': {'humidity': 58,
#           'pressure': 1019,
#           'temp': 55.35,
#           'temp_max': 59,
#           'temp_min': 51.8},
#  'name': 'Port Elizabeth',
#  'sys': {'country': 'US',
#          'id': 4902,
#          'sunrise': 1573472328,
#          'sunset': 1573508950,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'speed': 5.82}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 20.71, 'lon': -105.21},
#  'dt': 1573484866,
#  'id': 4004293,
#  'main': {'humidity': 78,
#           'pressure': 1012,
#           'temp': 80.04,
#           'temp_max': 81,
#           'temp_min': 78.8},
#  'name': 'Ixtapa',
#  'sys': {'country': 'MX',
#          'id': 7156,
#          'sunrise': 1573477705,
#          'sunset': 1573518085,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 24140,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 108, 'speed': 3.06}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -33.93, 'lon': 18.42},
#  'dt': 1573484708,
#  'id': 3369157,
#  'main': {'humidity': 77,
#           'pressure': 1011,
#           'temp': 65.43,
#           'temp_max': 66.2,
#           'temp_min': 64},
#  'name': 'Cape Town',
#  'sys': {'country': 'ZA',
#          'id': 1899,
#          'sunrise': 1573443456,
#          'sunset': 1573492986,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 170, 'speed': 10.29}}
# {'base': 'model',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -38.31, 'lon': -60.23},
#  'dt': 1573484867,
#  'id': 3833859,
#  'main': {'grnd_level': 1010,
#           'humidity': 38,
#           'pressure': 1019,
#           'sea_level': 1019,
#           'temp': 78.17,
#           'temp_max': 78.17,
#           'temp_min': 78.17},
#  'name': 'Barrow',
#  'sys': {'country': 'AR', 'sunrise': 1573461787, 'sunset': 1573512411},
#  'timezone': -10800,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 351, 'speed': 17.18}}
# {'base': 'model',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -23.58, 'lon': 149.07},
#  'dt': 1573484867,
#  'id': 2175403,
#  'main': {'grnd_level': 995,
#           'humidity': 71,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 67.15,
#           'temp_max': 67.15,
#           'temp_min': 67.15},
#  'name': 'Bluff',
#  'sys': {'country': 'AU', 'sunrise': 1573499541, 'sunset': 1573546999},
#  'timezone': 36000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 65, 'speed': 7.07}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -54.81, 'lon': -68.31},
#  'dt': 1573484867,
#  'id': 3833367,
#  'main': {'humidity': 76,
#           'pressure': 1010,
#           'temp': 49.75,
#           'temp_max': 51.8,
#           'temp_min': 48.2},
#  'name': 'Ushuaia',
#  'sys': {'country': 'AR',
#          'id': 8303,
#          'sunrise': 1573460702,
#          'sunset': 1573517375,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 230, 'gust': 36.91, 'speed': 25.28}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -9.24, 'lon': -35.49},
#  'dt': 1573484867,
#  'id': 3388341,
#  'main': {'humidity': 51,
#           'pressure': 1013,
#           'temp': 86,
#           'temp_max': 86,
#           'temp_min': 86},
#  'name': 'Passo de Camaragibe',
#  'sys': {'country': 'BR',
#          'id': 8413,
#          'sunrise': 1573458649,
#          'sunset': 1573503673,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 100, 'speed': 11.41}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'model',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -23.12, 'lon': -134.97},
#  'dt': 1573484646,
#  'id': 4030556,
#  'main': {'grnd_level': 1013,
#           'humidity': 92,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 71.64,
#           'temp_max': 71.64,
#           'temp_min': 71.64},
#  'name': 'Rikitea',
#  'rain': {'3h': 4.75},
#  'sys': {'country': 'PF', 'sunrise': 1573481358, 'sunset': 1573528718},
#  'timezone': -32400,
#  'weather': [{'description': 'moderate rain',
#               'icon': '10d',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 152, 'speed': 25.05}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -53.16, 'lon': -70.91},
#  'dt': 1573484868,
#  'id': 3874787,
#  'main': {'humidity': 58,
#           'pressure': 1013,
#           'temp': 55.26,
#           'temp_max': 57,
#           'temp_min': 53.6},
#  'name': 'Punta Arenas',
#  'sys': {'country': 'CL',
#          'id': 8487,
#          'sunrise': 1573461745,
#          'sunset': 1573517580,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 260, 'speed': 24.16}}
# {'base': 'model',
#  'clouds': {'all': 2},
#  'cod': 200,
#  'coord': {'lat': 10.57, 'lon': 72.64},
#  'dt': 1573484868,
#  'id': 1267390,
#  'main': {'grnd_level': 1011,
#           'humidity': 75,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 81.64,
#           'temp_max': 81.64,
#           'temp_min': 81.64},
#  'name': 'Kavaratti',
#  'sys': {'country': 'IN', 'sunrise': 1573434194, 'sunset': 1573476221},
#  'timezone': 19800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 5, 'speed': 5.32}}
# {'base': 'model',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 29.96, 'lon': 122.3},
#  'dt': 1573484868,
#  'id': 1795632,
#  'main': {'grnd_level': 1019,
#           'humidity': 53,
#           'pressure': 1020,
#           'sea_level': 1020,
#           'temp': 66.11,
#           'temp_max': 66.11,
#           'temp_min': 66.11},
#  'name': 'Shenjiamen',
#  'sys': {'country': 'CN', 'sunrise': 1573423917, 'sunset': 1573462659},
#  'timezone': 28800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 65, 'speed': 8.75}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -34.42, 'lon': 19.24},
#  'dt': 1573484868,
#  'id': 3366880,
#  'main': {'humidity': 84,
#           'pressure': 1006,
#           'temp': 66.67,
#           'temp_max': 70,
#           'temp_min': 64},
#  'name': 'Hermanus',
#  'rain': {'3h': 1.19},
#  'sys': {'country': 'ZA',
#          'id': 2006131,
#          'sunrise': 1573443203,
#          'sunset': 1573492846,
#          'type': 3},
#  'timezone': 7200,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 143, 'gust': 8.99, 'speed': 1.99}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.64, 'lon': 115.35},
#  'dt': 1573484868,
#  'id': 2075265,
#  'main': {'humidity': 34,
#           'pressure': 1014,
#           'temp': 55.26,
#           'temp_max': 59,
#           'temp_min': 53.01},
#  'name': 'Busselton',
#  'sys': {'country': 'AU',
#          'id': 2011706,
#          'sunrise': 1573420238,
#          'sunset': 1573469674,
#          'type': 3},
#  'timezone': 28800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 121, 'speed': 20.62}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 39.23, 'lon': 106.34},
#  'dt': 1573484869,
#  'id': 1794971,
#  'main': {'humidity': 19,
#           'pressure': 834,
#           'temp': 46.99,
#           'temp_max': 46.99,
#           'temp_min': 46.99},
#  'name': 'Shitanjing',
#  'sys': {'country': 'CN',
#          'id': 2000025,
#          'sunrise': 1573428767,
#          'sunset': 1573465471,
#          'type': 3},
#  'timezone': 28800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'gust': 3, 'speed': 1.01}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 58.3, 'lon': -134.42},
#  'dt': 1573484869,
#  'id': 5554072,
#  'main': {'humidity': 92,
#           'pressure': 1019,
#           'temp': 28.4,
#           'temp_max': 28.4,
#           'temp_min': 28.4},
#  'name': 'Juneau',
#  'sys': {'country': 'US',
#          'id': 7729,
#          'sunrise': 1573490187,
#          'sunset': 1573519625,
#          'type': 1},
#  'timezone': -32400,
#  'visibility': 16093,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 92, 'speed': 4.43}}
# {'base': 'stations',
#  'clouds': {'all': 99},
#  'cod': 200,
#  'coord': {'lat': -33.59, 'lon': 26.89},
#  'dt': 1573484870,
#  'id': 964432,
#  'main': {'humidity': 96,
#           'pressure': 1010,
#           'temp': 64,
#           'temp_max': 64,
#           'temp_min': 64},
#  'name': 'Port Alfred',
#  'sys': {'country': 'ZA',
#          'id': 2011314,
#          'sunrise': 1573441463,
#          'sunset': 1573490913,
#          'type': 3},
#  'timezone': 7200,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 39, 'gust': 17, 'speed': 8.99}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 45.36, 'lon': -73.48},
#  'dt': 1573484870,
#  'id': 6138908,
#  'main': {'humidity': 67,
#           'pressure': 1026,
#           'temp': 23.31,
#           'temp_max': 26.01,
#           'temp_min': 21},
#  'name': 'Saint-Philippe',
#  'sys': {'country': 'CA',
#          'id': 820,
#          'sunrise': 1573472806,
#          'sunset': 1573507752,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 14484,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 40, 'speed': 9.17}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 59.92, 'lon': 5.78},
#  'dt': 1573484871,
#  'id': 3133472,
#  'main': {'humidity': 59,
#           'pressure': 1001,
#           'temp': 35.92,
#           'temp_max': 37,
#           'temp_min': 35.01},
#  'name': 'Hellvik',
#  'sys': {'country': 'NO',
#          'id': 1677,
#          'sunrise': 1573456992,
#          'sunset': 1573485519,
#          'type': 1},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 100, 'speed': 6.93}}
# {'base': 'model',
#  'clouds': {'all': 19},
#  'cod': 200,
#  'coord': {'lat': 3.07, 'lon': 172.79},
#  'dt': 1573484871,
#  'id': 2110227,
#  'main': {'grnd_level': 1009,
#           'humidity': 74,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 82.92,
#           'temp_max': 82.92,
#           'temp_min': 82.92},
#  'name': 'Butaritari',
#  'rain': {'3h': 2},
#  'sys': {'country': 'KI', 'sunrise': 1573496000, 'sunset': 1573539154},
#  'timezone': 43200,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 13, 'speed': 4.9}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 18.64, 'lon': 72.88},
#  'dt': 1573484871,
#  'id': 1279027,
#  'main': {'humidity': 70,
#           'pressure': 1010,
#           'temp': 86,
#           'temp_max': 86,
#           'temp_min': 86},
#  'name': 'Alibag',
#  'sys': {'country': 'IN',
#          'id': 9052,
#          'sunrise': 1573434774,
#          'sunset': 1573475525,
#          'type': 1},
#  'timezone': 19800,
#  'visibility': 3000,
#  'weather': [{'description': 'haze', 'icon': '50n', 'id': 721, 'main': 'Haze'}],
#  'wind': {'deg': 330, 'speed': 5.82}}
# {'base': 'model',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': -8.93, 'lon': 125.41},
#  'dt': 1573484696,
#  'id': 1651810,
#  'main': {'grnd_level': 906,
#           'humidity': 79,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 66.7,
#           'temp_max': 66.7,
#           'temp_min': 66.7},
#  'name': 'Airai',
#  'sys': {'country': 'TL', 'sunrise': 1573506455, 'sunset': 1573551443},
#  'timezone': 32400,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 47, 'speed': 2.48}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 69.44, 'lon': -133.03},
#  'dt': 1573484871,
#  'id': 6170031,
#  'main': {'humidity': 92,
#           'pressure': 1014,
#           'temp': 26.6,
#           'temp_max': 26.6,
#           'temp_min': 26.6},
#  'name': 'Tuktoyaktuk',
#  'sys': {'country': 'CA',
#          'id': 942,
#          'sunrise': 1573495595,
#          'sunset': 1573513550,
#          'type': 1},
#  'timezone': -25200,
#  'visibility': 2414,
#  'weather': [{'description': 'mist', 'icon': '50n', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 290, 'gust': 28.86, 'speed': 21.92}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 15.34, 'lon': 74.49},
#  'dt': 1573484871,
#  'id': 1273574,
#  'main': {'humidity': 73,
#           'pressure': 1015,
#           'temp': 73.4,
#           'temp_max': 73.4,
#           'temp_min': 73.4},
#  'name': 'Vaini',
#  'sys': {'country': 'IN',
#          'id': 9229,
#          'sunrise': 1573434121,
#          'sunset': 1573475405,
#          'type': 1},
#  'timezone': 19800,
#  'visibility': 6000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 90, 'speed': 4.7}}
# {'base': 'model',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 34.16, 'lon': 77.58},
#  'dt': 1573484726,
#  'id': 1264976,
#  'main': {'grnd_level': 604,
#           'humidity': 87,
#           'pressure': 1029,
#           'sea_level': 1029,
#           'temp': 17.78,
#           'temp_max': 17.78,
#           'temp_min': 17.78},
#  'name': 'Leh',
#  'snow': {'3h': 0.19},
#  'sys': {'country': 'IN', 'sunrise': 1573435089, 'sunset': 1573472955},
#  'timezone': 19800,
#  'weather': [{'description': 'light snow',
#               'icon': '13n',
#               'id': 600,
#               'main': 'Snow'}],
#  'wind': {'deg': 228, 'speed': 2.62}}
# {'base': 'model',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 49.99, 'lon': 88.66},
#  'dt': 1573484872,
#  'id': 1502422,
#  'main': {'grnd_level': 806,
#           'humidity': 71,
#           'pressure': 1045,
#           'sea_level': 1045,
#           'temp': -2.85,
#           'temp_max': -2.85,
#           'temp_min': -2.85},
#  'name': 'Kosh-Agach',
#  'sys': {'country': 'RU', 'sunrise': 1573434632, 'sunset': 1573468093},
#  'timezone': 25200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 352, 'speed': 6.38}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -0.74, 'lon': -90.35},
#  'dt': 1573484652,
#  'id': 3652764,
#  'main': {'humidity': 60,
#           'pressure': 1015,
#           'temp': 73.81,
#           'temp_max': 75.2,
#           'temp_min': 72},
#  'name': 'Puerto Ayora',
#  'sys': {'country': 'EC',
#          'id': 8521,
#          'sunrise': 1573472464,
#          'sunset': 1573516193,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 220, 'speed': 6.93}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 37.61, 'lon': -122.49},
#  'dt': 1573484874,
#  'id': 5380420,
#  'main': {'humidity': 93,
#           'pressure': 1018,
#           'temp': 48.02,
#           'temp_max': 55,
#           'temp_min': 42.8},
#  'name': 'Pacifica',
#  'rain': {},
#  'sys': {'country': 'US',
#          'id': 5154,
#          'sunrise': 1573483531,
#          'sunset': 1573520554,
#          'type': 1},
#  'timezone': -28800,
#  'visibility': 9656,
#  'weather': [{'description': 'mist', 'icon': '50d', 'id': 701, 'main': 'Mist'},
#              {'description': 'fog', 'icon': '50d', 'id': 741, 'main': 'Fog'}],
#  'wind': {'deg': 170, 'speed': 3.36}}
# {'base': 'model',
#  'clouds': {'all': 99},
#  'cod': 200,
#  'coord': {'lat': 72.79, 'lon': -56.15},
#  'dt': 1573484654,
#  'id': 3418910,
#  'main': {'grnd_level': 995,
#           'humidity': 63,
#           'pressure': 997,
#           'sea_level': 997,
#           'temp': 23.41,
#           'temp_max': 23.41,
#           'temp_min': 23.41},
#  'name': 'Upernavik',
#  'sys': {'country': 'GL', 'sunrise': 1573482183, 'sunset': 1573490056},
#  'timezone': -10800,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 60, 'speed': 3.74}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -33.02, 'lon': 27.91},
#  'dt': 1573484655,
#  'id': 1006984,
#  'main': {'humidity': 100,
#           'pressure': 1012,
#           'temp': 64.4,
#           'temp_max': 64.4,
#           'temp_min': 64.4},
#  'name': 'East London',
#  'sys': {'country': 'ZA',
#          'id': 1912,
#          'sunrise': 1573441283,
#          'sunset': 1573490604,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 2200,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'},
#              {'description': 'mist', 'icon': '50d', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 60, 'speed': 16.11}}
# {'base': 'stations',
#  'clouds': {'all': 79},
#  'cod': 200,
#  'coord': {'lat': -34.53, 'lon': 20.04},
#  'dt': 1573484875,
#  'id': 1015776,
#  'main': {'humidity': 68,
#           'pressure': 1011,
#           'temp': 69.91,
#           'temp_max': 70,
#           'temp_min': 69.8},
#  'name': 'Bredasdorp',
#  'rain': {'3h': 0.13},
#  'sys': {'country': 'ZA',
#          'id': 1966,
#          'sunrise': 1573442998,
#          'sunset': 1573492667,
#          'type': 1},
#  'timezone': 7200,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 160, 'speed': 20.8}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 42.65, 'lon': -73.75},
#  'dt': 1573484657,
#  'id': 5106834,
#  'main': {'humidity': 95,
#           'pressure': 1020,
#           'temp': 36.9,
#           'temp_max': 45,
#           'temp_min': 30.2},
#  'name': 'Albany',
#  'rain': {},
#  'sys': {'country': 'US',
#          'id': 3797,
#          'sunrise': 1573472474,
#          'sunset': 1573508214,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 16093,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 341, 'speed': 2.59}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'model',
#  'clouds': {'all': 89},
#  'cod': 200,
#  'coord': {'lat': 10.31, 'lon': 9.75},
#  'dt': 1573484875,
#  'id': 2347470,
#  'main': {'grnd_level': 942,
#           'humidity': 21,
#           'pressure': 1004,
#           'sea_level': 1004,
#           'temp': 94.69,
#           'temp_max': 94.69,
#           'temp_min': 94.69},
#  'name': 'Miri',
#  'sys': {'country': 'NG', 'sunrise': 1573449271, 'sunset': 1573491334},
#  'timezone': 3600,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 84, 'speed': 6.71}}
# {'base': 'model',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 13.79, 'lon': -15.05},
#  'dt': 1573484875,
#  'id': 2413070,
#  'main': {'grnd_level': 1000,
#           'humidity': 11,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 103.62,
#           'temp_max': 103.62,
#           'temp_min': 103.62},
#  'name': 'Nioro',
#  'sys': {'country': 'GM', 'sunrise': 1573455495, 'sunset': 1573497015},
#  'timezone': 0,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 65, 'speed': 10.02}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 62.45, 'lon': -114.38},
#  'dt': 1573484822,
#  'id': 6185377,
#  'main': {'humidity': 84,
#           'pressure': 1013,
#           'temp': 8.65,
#           'temp_max': 12.99,
#           'temp_min': 6.01},
#  'name': 'Yellowknife',
#  'sys': {'country': 'CA',
#          'id': 1007,
#          'sunrise': 1573486817,
#          'sunset': 1573513375,
#          'type': 1},
#  'timezone': -25200,
#  'visibility': 24140,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'speed': 2.24}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 40.6, 'lon': -124.16},
#  'dt': 1573484876,
#  'id': 5563839,
#  'main': {'humidity': 100,
#           'pressure': 1019,
#           'temp': 44.49,
#           'temp_max': 46,
#           'temp_min': 42.8},
#  'name': 'Fortuna',
#  'rain': {},
#  'sys': {'country': 'US',
#          'id': 4127,
#          'sunrise': 1573484306,
#          'sunset': 1573520581,
#          'type': 1},
#  'timezone': -28800,
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 150, 'speed': 8.05}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -34.58, 'lon': 150.85},
#  'dt': 1573484877,
#  'id': 6255012,
#  'main': {'humidity': 62,
#           'pressure': 1009,
#           'temp': 60.78,
#           'temp_max': 71.01,
#           'temp_min': 53.01},
#  'name': 'Flinders',
#  'sys': {'country': 'AU',
#          'id': 9594,
#          'sunrise': 1573497970,
#          'sunset': 1573547716,
#          'type': 1},
#  'timezone': 39600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 360, 'speed': 6.93}}
# {'base': 'model',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 5.48, 'lon': -53.21},
#  'dt': 1573484878,
#  'id': 3381428,
#  'main': {'grnd_level': 1010,
#           'humidity': 81,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 82.06,
#           'temp_max': 82.06,
#           'temp_min': 82.06},
#  'name': 'Iracoubo',
#  'sys': {'country': 'GF', 'sunrise': 1573464017, 'sunset': 1573506811},
#  'timezone': -10800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 82, 'speed': 11.54}}
# {'base': 'model',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -30.97, 'lon': 22.13},
#  'dt': 1573484878,
#  'id': 1014034,
#  'main': {'grnd_level': 862,
#           'humidity': 10,
#           'pressure': 1002,
#           'sea_level': 1002,
#           'temp': 82.72,
#           'temp_max': 82.72,
#           'temp_min': 82.72},
#  'name': 'Carnarvon',
#  'sys': {'country': 'ZA', 'sunrise': 1573442894, 'sunset': 1573491768},
#  'timezone': 7200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 285, 'speed': 20.45}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 67},
#  'cod': 200,
#  'coord': {'lat': -46.19, 'lon': 168.86},
#  'dt': 1573484649,
#  'id': 6201424,
#  'main': {'humidity': 84,
#           'pressure': 1006,
#           'temp': 43,
#           'temp_max': 43,
#           'temp_min': 43},
#  'name': 'Mataura',
#  'sys': {'country': 'NZ',
#          'id': 2008959,
#          'sunrise': 1573491998,
#          'sunset': 1573545042,
#          'type': 3},
#  'timezone': 46800,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 310, 'gust': 4, 'speed': 1.01}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 5.28, 'lon': 115.24},
#  'dt': 1573484878,
#  'id': 1733782,
#  'main': {'humidity': 74,
#           'pressure': 1011,
#           'temp': 84.09,
#           'temp_max': 84.2,
#           'temp_min': 84},
#  'name': 'Victoria',
#  'sys': {'country': 'BN',
#          'id': 9372,
#          'sunrise': 1573423568,
#          'sunset': 1573466398,
#          'type': 1},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 30, 'speed': 4.7}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': -46.13, 'lon': 167.69},
#  'dt': 1573484878,
#  'id': 2180815,
#  'main': {'humidity': 84,
#           'pressure': 1006,
#           'temp': 43,
#           'temp_max': 43,
#           'temp_min': 43},
#  'name': 'Tuatapere',
#  'sys': {'country': 'NZ',
#          'id': 2008959,
#          'sunrise': 1573492289,
#          'sunset': 1573545312,
#          'type': 3},
#  'timezone': 46800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 310, 'gust': 4, 'speed': 1.01}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 28.58, 'lon': 77.04},
#  'dt': 1573484879,
#  'id': 1273294,
#  'main': {'humidity': 49,
#           'pressure': 1013,
#           'temp': 69.8,
#           'temp_max': 69.8,
#           'temp_min': 69.8},
#  'name': 'Dwarka',
#  'sys': {'country': 'IN',
#          'id': 9165,
#          'sunrise': 1573434652,
#          'sunset': 1573473651,
#          'type': 1},
#  'timezone': 19800,
#  'visibility': 2000,
#  'weather': [{'description': 'haze', 'icon': '50n', 'id': 721, 'main': 'Haze'}],
#  'wind': {'deg': 344, 'speed': 5.26}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'model',
#  'clouds': {'all': 28},
#  'cod': 200,
#  'coord': {'lat': -0.6, 'lon': 73.08},
#  'dt': 1573484879,
#  'id': 1282256,
#  'main': {'grnd_level': 1010,
#           'humidity': 73,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 83.57,
#           'temp_max': 83.57,
#           'temp_min': 83.57},
#  'name': 'Hithadhoo',
#  'sys': {'country': 'MV', 'sunrise': 1573433248, 'sunset': 1573476955},
#  'timezone': 18000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 92, 'speed': 8.77}}
# {'base': 'model',
#  'clouds': {'all': 68},
#  'cod': 200,
#  'coord': {'lat': 36.91, 'lon': 43.06},
#  'dt': 1573484879,
#  'id': 90708,
#  'main': {'grnd_level': 927,
#           'humidity': 22,
#           'pressure': 1019,
#           'sea_level': 1019,
#           'temp': 59.31,
#           'temp_max': 59.31,
#           'temp_min': 59.31},
#  'name': 'Sandur',
#  'sys': {'country': 'IQ', 'sunrise': 1573443687, 'sunset': 1573480927},
#  'timezone': 10800,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 265, 'speed': 0.94}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 36.3, 'lon': -76.22},
#  'dt': 1573484604,
#  'id': 4465088,
#  'main': {'humidity': 58,
#           'pressure': 1022,
#           'temp': 58.05,
#           'temp_max': 60.8,
#           'temp_min': 55},
#  'name': 'Elizabeth City',
#  'sys': {'country': 'US',
#          'id': 5216,
#          'sunrise': 1573472265,
#          'sunset': 1573509609,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 220, 'speed': 9.17}}
# {'base': 'model',
#  'clouds': {'all': 59},
#  'cod': 200,
#  'coord': {'lat': -33.69, 'lon': -53.46},
#  'dt': 1573484879,
#  'id': 3443061,
#  'main': {'grnd_level': 1023,
#           'humidity': 64,
#           'pressure': 1024,
#           'sea_level': 1024,
#           'temp': 68.76,
#           'temp_max': 68.76,
#           'temp_min': 68.76},
#  'name': 'Chuy',
#  'sys': {'country': 'UY', 'sunrise': 1573460726, 'sunset': 1573510222},
#  'timezone': -10800,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 87, 'speed': 12.64}}
# {'base': 'model',
#  'clouds': {'all': 51},
#  'cod': 200,
#  'coord': {'lat': 70.62, 'lon': 147.9},
#  'dt': 1573484880,
#  'id': 2126123,
#  'main': {'grnd_level': 1014,
#           'humidity': 96,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': -4.02,
#           'temp_max': -4.02,
#           'temp_min': -4.02},
#  'name': 'Chokurdakh',
#  'sys': {'country': 'RU', 'sunrise': 1573515938, 'sunset': 1573531164},
#  'timezone': 39600,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 236, 'speed': 1.12}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'model',
#  'clouds': {'all': 99},
#  'cod': 200,
#  'coord': {'lat': 65.58, 'lon': -170.99},
#  'dt': 1573484880,
#  'id': 4031637,
#  'main': {'grnd_level': 1006,
#           'humidity': 89,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 29.01,
#           'temp_max': 29.01,
#           'temp_min': 29.01},
#  'name': 'Lavrentiya',
#  'snow': {'3h': 0.44},
#  'sys': {'country': 'RU', 'sunrise': 1573588549, 'sunset': 1573611635},
#  'timezone': 43200,
#  'weather': [{'description': 'light snow',
#               'icon': '13n',
#               'id': 600,
#               'main': 'Snow'}],
#  'wind': {'deg': 26, 'speed': 16.13}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 17.01, 'lon': 54.1},
#  'dt': 1573484651,
#  'id': 286621,
#  'main': {'humidity': 54,
#           'pressure': 1011,
#           'temp': 82.4,
#           'temp_max': 82.4,
#           'temp_min': 82.4},
#  'name': 'Salalah',
#  'sys': {'country': 'OM',
#          'id': 7562,
#          'sunrise': 1573439150,
#          'sunset': 1573480164,
#          'type': 1},
#  'timezone': 14400,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 120, 'speed': 4.7}}
# {'base': 'model',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 31.86, 'lon': 10.98},
#  'dt': 1573484880,
#  'id': 2214433,
#  'main': {'grnd_level': 970,
#           'humidity': 53,
#           'pressure': 1006,
#           'sea_level': 1006,
#           'temp': 55.09,
#           'temp_max': 55.09,
#           'temp_min': 55.09},
#  'name': 'Nalut',
#  'sys': {'country': 'LY', 'sunrise': 1573450841, 'sunset': 1573489173},
#  'timezone': 7200,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 250, 'speed': 20.18}}
# {'base': 'model',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 64.42, 'lon': -173.23},
#  'dt': 1573484881,
#  'id': 4031574,
#  'main': {'grnd_level': 976,
#           'humidity': 98,
#           'pressure': 1006,
#           'sea_level': 1006,
#           'temp': 30.52,
#           'temp_max': 30.52,
#           'temp_min': 30.52},
#  'name': 'Provideniya',
#  'snow': {'3h': 3.19},
#  'sys': {'country': 'RU', 'sunrise': 1573588459, 'sunset': 1573612800},
#  'timezone': 43200,
#  'weather': [{'description': 'snow', 'icon': '13n', 'id': 601, 'main': 'Snow'}],
#  'wind': {'deg': 36, 'speed': 11.99}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 22.08, 'lon': -159.32},
#  'dt': 1573484662,
#  'id': 5848280,
#  'main': {'humidity': 94,
#           'pressure': 1016,
#           'temp': 72.99,
#           'temp_max': 73.4,
#           'temp_min': 72},
#  'name': 'Kapaa',
#  'rain': {},
#  'sys': {'country': 'US',
#          'id': 7873,
#          'sunrise': 1573490815,
#          'sunset': 1573530950,
#          'type': 1},
#  'timezone': -36000,
#  'visibility': 16093,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 280, 'speed': 5.82}}
# {'base': 'stations',
#  'clouds': {'all': 26},
#  'cod': 200,
#  'coord': {'lat': 37.52, 'lon': 140.86},
#  'dt': 1573484881,
#  'id': 2111704,
#  'main': {'humidity': 89,
#           'pressure': 996,
#           'temp': 48.76,
#           'temp_max': 55,
#           'temp_min': 41},
#  'name': 'Namie',
#  'sys': {'country': 'JP',
#          'id': 20784,
#          'sunrise': 1573506734,
#          'sunset': 1573543747,
#          'type': 3},
#  'timezone': 32400,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 249, 'speed': 6.96}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 31.89, 'lon': -85.15},
#  'dt': 1573484669,
#  'id': 4060954,
#  'main': {'humidity': 55,
#           'pressure': 1023,
#           'temp': 57.54,
#           'temp_max': 62.6,
#           'temp_min': 53.6},
#  'name': 'Eufaula',
#  'sys': {'country': 'US',
#          'id': 3816,
#          'sunrise': 1573473929,
#          'sunset': 1573512231,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 130, 'speed': 6.93}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -7.8, 'lon': -35.59},
#  'dt': 1573484882,
#  'id': 3405339,
#  'main': {'humidity': 51,
#           'pressure': 1014,
#           'temp': 84.2,
#           'temp_max': 84.2,
#           'temp_min': 84.2},
#  'name': 'Bom Jardim',
#  'sys': {'country': 'BR',
#          'id': 8392,
#          'sunrise': 1573458785,
#          'sunset': 1573503585,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 130, 'speed': 13.87}}
# {'base': 'model',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 71.97, 'lon': 114.09},
#  'dt': 1573484882,
#  'id': 2017155,
#  'main': {'grnd_level': 1003,
#           'humidity': 98,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': -6.87,
#           'temp_max': -6.87,
#           'temp_min': -6.87},
#  'name': 'Saskylakh',
#  'sys': {'country': 'RU', 'sunrise': 1573526169, 'sunset': 1573537163},
#  'timezone': 32400,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 276, 'speed': 3.29}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 38.52, 'lon': -28.7},
#  'dt': 1573484882,
#  'id': 3372707,
#  'main': {'humidity': 72,
#           'pressure': 1033,
#           'temp': 68,
#           'temp_max': 68,
#           'temp_min': 68},
#  'name': 'Ribeira Grande',
#  'sys': {'country': 'PT',
#          'id': 6883,
#          'sunrise': 1573461115,
#          'sunset': 1573497948,
#          'type': 1},
#  'timezone': -3600,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 200, 'speed': 4.7}}
# {'base': 'model',
#  'clouds': {'all': 2},
#  'cod': 200,
#  'coord': {'lat': -34.72, 'lon': 135.86},
#  'dt': 1573484671,
#  'id': 2063036,
#  'main': {'grnd_level': 1008,
#           'humidity': 75,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 52.75,
#           'temp_max': 52.75,
#           'temp_min': 52.75},
#  'name': 'Port Lincoln',
#  'sys': {'country': 'AU', 'sunrise': 1573501549, 'sunset': 1573551333},
#  'timezone': 37800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 209, 'speed': 17.76}}
# {'base': 'model',
#  'clouds': {'all': 93},
#  'cod': 200,
#  'coord': {'lat': -23.07, 'lon': -54.19},
#  'dt': 1573484882,
#  'id': 3456368,
#  'main': {'grnd_level': 975,
#           'humidity': 59,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 85.8,
#           'temp_max': 85.8,
#           'temp_min': 85.8},
#  'name': 'Navirai',
#  'sys': {'country': 'BR', 'sunrise': 1573461981, 'sunset': 1573509317},
#  'timezone': -14400,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 60, 'speed': 3.24}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -5.2, 'lon': -35.46},
#  'dt': 1573484883,
#  'id': 3386213,
#  'main': {'humidity': 48,
#           'pressure': 1011,
#           'temp': 87.8,
#           'temp_max': 87.8,
#           'temp_min': 87.8},
#  'name': 'Touros',
#  'sys': {'country': 'BR',
#          'id': 8452,
#          'sunrise': 1573458952,
#          'sunset': 1573503355,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 160, 'speed': 18.34}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 59.7, 'lon': 30.79},
#  'dt': 1573484883,
#  'id': 546105,
#  'main': {'humidity': 93,
#           'pressure': 1008,
#           'temp': 39.4,
#           'temp_max': 39.99,
#           'temp_min': 39},
#  'name': 'Nikolskoye',
#  'sys': {'country': 'RU',
#          'id': 8926,
#          'sunrise': 1573450906,
#          'sunset': 1573479598,
#          'type': 1},
#  'timezone': 10800,
#  'visibility': 5000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'},
#              {'description': 'mist', 'icon': '50n', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 280, 'speed': 8.95}}
# {'base': 'model',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 56.26, 'lon': 34.33},
#  'dt': 1573484883,
#  'id': 499717,
#  'main': {'grnd_level': 980,
#           'humidity': 90,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 45.81,
#           'temp_max': 45.81,
#           'temp_min': 45.81},
#  'name': 'Rzhev',
#  'rain': {'3h': 0.38},
#  'sys': {'country': 'RU', 'sunrise': 1573449057, 'sunset': 1573479748},
#  'timezone': 10800,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 182, 'speed': 10.89}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'model',
#  'clouds': {'all': 58},
#  'cod': 200,
#  'coord': {'lat': 9.23, 'lon': -78.02},
#  'dt': 1573484884,
#  'id': 3714956,
#  'main': {'grnd_level': 987,
#           'humidity': 64,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 86.04,
#           'temp_max': 86.04,
#           'temp_min': 86.04},
#  'name': 'Ailigandi',
#  'sys': {'country': 'PA', 'sunrise': 1573470258, 'sunset': 1573512480},
#  'timezone': -18000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 298, 'speed': 0.34}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 5.79, 'lon': 0.9},
#  'dt': 1573484884,
#  'id': 2304548,
#  'main': {'humidity': 70,
#           'pressure': 1008,
#           'temp': 86,
#           'temp_max': 86,
#           'temp_min': 86},
#  'name': 'Anloga',
#  'sys': {'country': 'GH',
#          'id': 1218,
#          'sunrise': 1573451052,
#          'sunset': 1573493801,
#          'type': 1},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 200, 'speed': 14.99}}
# {'base': 'model',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 28.88, 'lon': 112.34},
#  'dt': 1573484884,
#  'id': 1797543,
#  'main': {'grnd_level': 1011,
#           'humidity': 41,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 69.57,
#           'temp_max': 69.57,
#           'temp_min': 69.57},
#  'name': 'Tianpeng',
#  'sys': {'country': 'CN', 'sunrise': 1573426204, 'sunset': 1573465153},
#  'timezone': 28800,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 132, 'speed': 4.23}}
# {'base': 'model',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 32.38, 'lon': 15.09},
#  'dt': 1573484884,
#  'id': 2214846,
#  'main': {'grnd_level': 1000,
#           'humidity': 61,
#           'pressure': 1000,
#           'sea_level': 1000,
#           'temp': 76.46,
#           'temp_max': 76.46,
#           'temp_min': 76.46},
#  'name': 'Misratah',
#  'sys': {'country': 'LY', 'sunrise': 1573449907, 'sunset': 1573488134},
#  'timezone': 7200,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 107, 'speed': 12.68}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 7.15, 'lon': 125.66},
#  'dt': 1573484884,
#  'id': 1715348,
#  'main': {'humidity': 88,
#           'pressure': 1010,
#           'temp': 78.8,
#           'temp_max': 78.8,
#           'temp_min': 78.8},
#  'name': 'Panacan',
#  'sys': {'country': 'PH',
#          'id': 8154,
#          'sunrise': 1573421207,
#          'sunset': 1573463756,
#          'type': 1},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 300, 'speed': 3.36}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 49.72, 'lon': -86.95},
#  'dt': 1573484884,
#  'id': 5960603,
#  'main': {'humidity': 70,
#           'pressure': 1027,
#           'temp': -4.01,
#           'temp_max': -4.01,
#           'temp_min': -4.01},
#  'name': 'Geraldton',
#  'sys': {'country': 'CA',
#          'id': 810,
#          'sunrise': 1573476777,
#          'sunset': 1573510248,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 24140,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 300, 'speed': 9.17}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -20.34, 'lon': 57.76},
#  'dt': 1573484667,
#  'id': 1106677,
#  'main': {'humidity': 78,
#           'pressure': 1014,
#           'temp': 77.9,
#           'temp_max': 78.8,
#           'temp_min': 77},
#  'name': 'Bambous Virieux',
#  'sys': {'country': 'MU',
#          'id': 2061,
#          'sunrise': 1573435364,
#          'sunset': 1573482194,
#          'type': 1},
#  'timezone': 14400,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 100, 'speed': 8.05}}
# {'base': 'model',
#  'clouds': {'all': 31},
#  'cod': 200,
#  'coord': {'lat': -6.64, 'lon': -51.99},
#  'dt': 1573484885,
#  'id': 3388847,
#  'main': {'grnd_level': 980,
#           'humidity': 52,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 93.16,
#           'temp_max': 93.16,
#           'temp_min': 93.16},
#  'name': 'Sao Felix do Xingu',
#  'sys': {'country': 'BR', 'sunrise': 1573462810, 'sunset': 1573507433},
#  'timezone': -10800,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 197, 'speed': 2.71}}
# {'base': 'model',
#  'clouds': {'all': 58},
#  'cod': 200,
#  'coord': {'lat': -9.8, 'lon': -139.03},
#  'dt': 1573484886,
#  'id': 4020109,
#  'main': {'grnd_level': 1012,
#           'humidity': 71,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 79.23,
#           'temp_max': 79.23,
#           'temp_min': 79.23},
#  'name': 'Atuona',
#  'rain': {'3h': 0.31},
#  'sys': {'country': 'PF', 'sunrise': 1573483453, 'sunset': 1573528572},
#  'timezone': -34200,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 33, 'speed': 6.69}}
# {'base': 'model',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -0.92, 'lon': 100.36},
#  'dt': 1573484672,
#  'id': 1633419,
#  'main': {'grnd_level': 937,
#           'humidity': 96,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 68.7,
#           'temp_max': 68.7,
#           'temp_min': 68.7},
#  'name': 'Padang',
#  'rain': {'3h': 0.13},
#  'sys': {'country': 'ID', 'sunrise': 1573426677, 'sunset': 1573470431},
#  'timezone': 25200,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
# ...
#  'sys': {'country': 'CA',
#          'id': 1000,
#          'sunrise': 1573475636,
#          'sunset': 1573509219,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 24140,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 290, 'speed': 6.93}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 45.62, 'lon': -74.6},
#  'dt': 1573484997,
#  'id': 5966843,
#  'main': {'humidity': 62,
#           'pressure': 1025,
#           'temp': 23.2,
#           'temp_max': 25,
#           'temp_min': 21},
#  'name': 'Grenville',
#  'sys': {'country': 'CA',
#          'id': 861,
#          'sunrise': 1573473115,
#          'sunset': 1573507981,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 40233,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 50, 'speed': 5.82}}
# {'base': 'model',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 54.43, 'lon': 31.9},
#  'dt': 1573484997,
#  'id': 525426,
#  'main': {'grnd_level': 984,
#           'humidity': 95,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 47.48,
#           'temp_max': 47.48,
#           'temp_min': 47.48},
#  'name': 'Sobolevo',
#  'rain': {'3h': 0.56},
#  'sys': {'country': 'RU', 'sunrise': 1573449192, 'sunset': 1573480779},
#  'timezone': 10800,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 219, 'speed': 11.56}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -4.26, 'lon': -55.99},
#  'dt': 1573484997,
#  'id': 3397967,
#  'main': {'humidity': 66,
#           'pressure': 1010,
#           'temp': 89.6,
#           'temp_max': 89.6,
#           'temp_min': 89.6},
#  'name': 'Itaituba',
#  'sys': {'country': 'BR',
#          'id': 8368,
#          'sunrise': 1573463951,
#          'sunset': 1573508211,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 9000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 120, 'speed': 8.05}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -6.53, 'lon': 110.7},
#  'dt': 1573484997,
#  'id': 1635164,
#  'main': {'humidity': 58,
#           'pressure': 1011,
#           'temp': 84.2,
#           'temp_max': 84.2,
#           'temp_min': 84.2},
#  'name': 'Mlonggo',
#  'sys': {'country': 'ID',
#          'id': 9362,
#          'sunrise': 1573423773,
#          'sunset': 1573468371,
#          'type': 1},
#  'timezone': 25200,
#  'visibility': 6000,
#  'weather': [{'description': 'thunderstorm',
#               'icon': '11n',
#               'id': 211,
#               'main': 'Thunderstorm'}],
#  'wind': {'deg': 80, 'speed': 8.05}}
# {'base': 'model',
#  'clouds': {'all': 36},
#  'cod': 200,
#  'coord': {'lat': 49.76, 'lon': 31.46},
#  'dt': 1573484997,
#  'id': 706900,
#  'main': {'grnd_level': 1004,
#           'humidity': 87,
#           'pressure': 1016,
#           'sea_level': 1016,
#           'temp': 52.36,
#           'temp_max': 52.36,
#           'temp_min': 52.36},
#  'name': 'Kaniv',
#  'sys': {'country': 'UA', 'sunrise': 1573448333, 'sunset': 1573481850},
#  'timezone': 7200,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 266, 'speed': 6.51}}
# {'base': 'model',
#  'clouds': {'all': 99},
#  'cod': 200,
#  'coord': {'lat': 63.9, 'lon': 122.77},
#  'dt': 1573484997,
#  'id': 2021017,
#  'main': {'grnd_level': 1003,
#           'humidity': 95,
#           'pressure': 1024,
#           'sea_level': 1024,
#           'temp': -18.01,
#           'temp_max': -18.01,
#           'temp_min': -18.01},
#  'name': 'Kysyl-Syr',
#  'sys': {'country': 'RU', 'sunrise': 1573517002, 'sunset': 1573542164},
#  'timezone': 32400,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 280, 'speed': 4.43}}
# {'base': 'model',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 65.96, 'lon': 78.37},
#  'dt': 1573484998,
#  'id': 1488414,
#  'main': {'grnd_level': 1027,
#           'humidity': 88,
#           'pressure': 1031,
#           'sea_level': 1031,
#           'temp': -6.88,
#           'temp_max': -6.88,
#           'temp_min': -6.88},
#  'name': 'Urengoy',
#  'sys': {'country': 'RU', 'sunrise': 1573442145, 'sunset': 1573465519},
#  'timezone': 18000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 184, 'speed': 7.05}}
# {'base': 'model',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 67.68, 'lon': 53.15},
#  'dt': 1573484998,
#  'id': 866062,
#  'main': {'grnd_level': 1016,
#           'humidity': 97,
#           'pressure': 1021,
#           'sea_level': 1021,
#           'temp': -0.86,
#           'temp_max': -0.86,
#           'temp_min': -0.86},
#  'name': 'Iskateley',
#  'sys': {'country': 'RU', 'sunrise': 1573449311, 'sunset': 1573470460},
#  'timezone': 10800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 37, 'speed': 8.86}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -9.47, 'lon': 147.16},
#  'dt': 1573484998,
#  'id': 2088122,
#  'main': {'humidity': 88,
#           'pressure': 1011,
#           'temp': 75.2,
#           'temp_max': 75.2,
#           'temp_min': 75.2},
#  'name': 'Port Moresby',
#  'sys': {'country': 'PG',
#          'id': 42,
#          'sunrise': 1573501193,
#          'sunset': 1573546264,
#          'type': 1},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 140, 'speed': 11.41}}
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': 70.86, 'lon': 29.09},
#  'dt': 1573484998,
#  'id': 780687,
#  'main': {'humidity': 79,
#           'pressure': 1019,
#           'temp': 24.21,
#           'temp_max': 24.8,
#           'temp_min': 23},
#  'name': 'Berlevag',
#  'sys': {'country': 'NO',
#          'id': 1618,
#          'sunrise': 1573458084,
#          'sunset': 1573473236,
#          'type': 1},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 200, 'speed': 9.17}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 42.35, 'lon': 14.4},
#  'dt': 1573484998,
#  'id': 3171886,
#  'main': {'humidity': 67,
#           'pressure': 1011,
#           'temp': 59.77,
#           'temp_max': 60.8,
#           'temp_min': 57.99},
#  'name': 'Ortona',
#  'sys': {'country': 'IT',
#          'id': 6687,
#          'sunrise': 1573451258,
#          'sunset': 1573487115,
#          'type': 1},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 30, 'speed': 4.7}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 54.78, 'lon': -127.17},
#  'dt': 1573484999,
#  'id': 6149996,
#  'main': {'humidity': 67,
#           'pressure': 1027,
#           'temp': 23,
#           'temp_max': 23,
#           'temp_min': 23},
#  'name': 'Smithers',
#  'sys': {'country': 'CA',
#          'id': 990,
#          'sunrise': 1573487505,
#          'sunset': 1573518827,
#          'type': 1},
#  'timezone': -28800,
#  'visibility': 14484,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 160, 'speed': 8.05}}
# {'base': 'model',
#  'clouds': {'all': 60},
#  'cod': 200,
#  'coord': {'lat': 48.68, 'lon': 71.64},
#  'dt': 1573484999,
#  'id': 1526041,
#  'main': {'grnd_level': 978,
#           'humidity': 28,
#           'pressure': 1040,
#           'sea_level': 1040,
#           'temp': 27.05,
#           'temp_max': 27.05,
#           'temp_min': 27.05},
#  'name': 'Atasu',
#  'sys': {'country': 'KZ', 'sunrise': 1573438486, 'sunset': 1573472409},
#  'timezone': 21600,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 176, 'speed': 4.9}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 50.7, 'lon': -127.42},
#  'dt': 1573484999,
#  'id': 6111862,
#  'main': {'humidity': 93,
#           'pressure': 1022,
#           'temp': 48.2,
#           'temp_max': 48.2,
#           'temp_min': 48.2},
#  'name': 'Port Hardy',
#  'sys': {'country': 'CA',
#          'id': 1011,
#          'sunrise': 1573486686,
#          'sunset': 1573519766,
#          'type': 1},
#  'timezone': -28800,
#  'visibility': 24140,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 110, 'gust': 33.33, 'speed': 24.16}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 49.47, 'lon': -123.76},
#  'dt': 1573484999,
#  'id': 6143367,
#  'main': {'humidity': 100,
#           'pressure': 1027,
#           'temp': 42.6,
#           'temp_max': 46,
#           'temp_min': 39.2},
#  'name': 'Sechelt',
#  'sys': {'country': 'CA',
#          'id': 761,
#          'sunrise': 1573485575,
#          'sunset': 1573519120,
#          'type': 1},
#  'timezone': -28800,
#  'visibility': 24140,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'speed': 2.24}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 16.99, 'lon': -99.26},
#  'dt': 1573484999,
#  'id': 3532499,
#  'main': {'humidity': 79,
#           'pressure': 1013,
#           'temp': 84.2,
#           'temp_max': 84.2,
#           'temp_min': 84.2},
#  'name': 'Tecoanapa',
#  'sys': {'country': 'MX',
#          'id': 7103,
#          'sunrise': 1573475968,
#          'sunset': 1573516966,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 12874,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 9, 'speed': 1.72}}
# {'base': 'model',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 58.16, 'lon': 36.77},
#  'dt': 1573484999,
#  'id': 525509,
#  'main': {'grnd_level': 990,
#           'humidity': 91,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 45.57,
#           'temp_max': 45.57,
#           'temp_min': 45.57},
#  'name': 'Molokovo',
#  'sys': {'country': 'RU', 'sunrise': 1573448994, 'sunset': 1573478640},
#  'timezone': 10800,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 186, 'speed': 11.39}}
# {'base': 'model',
#  'clouds': {'all': 49},
#  'cod': 200,
#  'coord': {'lat': -0.61, 'lon': -47.36},
#  'dt': 1573484999,
#  'id': 3389822,
#  'main': {'grnd_level': 1010,
#           'humidity': 79,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 81.72,
#           'temp_max': 81.72,
#           'temp_min': 81.72},
#  'name': 'Salinopolis',
#  'sys': {'country': 'BR', 'sunrise': 1573462155, 'sunset': 1573505864},
#  'timezone': -10800,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 75, 'speed': 17.02}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 0.05, 'lon': -51.07},
#  'dt': 1573484983,
#  'id': 3396016,
#  'main': {'humidity': 52,
#           'pressure': 1011,
#           'temp': 93.2,
#           'temp_max': 93.2,
#           'temp_min': 93.2},
#  'name': 'Macapa',
#  'sys': {'country': 'BR',
#          'id': 8415,
#          'sunrise': 1573463095,
#          'sunset': 1573506705,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 60, 'speed': 13.87}}
# {'base': 'model',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -16.78, 'lon': -151.5},
#  'dt': 1573485000,
#  'id': 4033375,
#  'main': {'grnd_level': 1012,
#           'humidity': 84,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 77.94,
#           'temp_max': 77.94,
#           'temp_min': 77.94},
#  'name': 'Tevaitoa',
#  'sys': {'country': 'PF', 'sunrise': 1573485881, 'sunset': 1573532131},
#  'timezone': -36000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 126, 'speed': 15.48}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -23.65, 'lon': -70.4},
#  'dt': 1573485000,
#  'id': 3899539,
#  'main': {'humidity': 63,
#           'pressure': 1014,
#           'temp': 64.4,
#           'temp_max': 64.4,
#           'temp_min': 64.4},
#  'name': 'Antofagasta',
#  'sys': {'country': 'CL',
#          'id': 8488,
#          'sunrise': 1573465817,
#          'sunset': 1573513263,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 200, 'speed': 10.29}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 3.63, 'lon': 9.81},
#  'dt': 1573485000,
#  'id': 2225940,
#  'main': {'humidity': 79,
#           'pressure': 1006,
#           'temp': 84.2,
#           'temp_max': 84.2,
#           'temp_min': 84.2},
#  'name': 'Yatou',
#  'sys': {'country': 'CM',
#          'id': 2090,
#          'sunrise': 1573448751,
#          'sunset': 1573491825,
#          'type': 1},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'thunderstorm',
#               'icon': '11d',
#               'id': 211,
#               'main': 'Thunderstorm'}],
#  'wind': {'speed': 3.36}}
# {'base': 'model',
#  'clouds': {'all': 99},
#  'cod': 200,
#  'coord': {'lat': 53.07, 'lon': 76.1},
#  'dt': 1573485000,
#  'id': 1523662,
#  'main': {'grnd_level': 1028,
#           'humidity': 52,
#           'pressure': 1041,
#           'sea_level': 1041,
#           'temp': 20.39,
#           'temp_max': 20.39,
#           'temp_min': 20.39},
#  'name': 'Kachiry',
#  'sys': {'country': 'KZ', 'sunrise': 1573438265, 'sunset': 1573470489},
#  'timezone': 21600,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 168, 'speed': 11.7}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 35.2, 'lon': -111.65},
#  'dt': 1573484833,
#  'id': 5294810,
#  'main': {'humidity': 47,
#           'pressure': 1023,
#           'temp': 44.73,
#           'temp_max': 53.6,
#           'temp_min': 32},
#  'name': 'Flagstaff',
#  'sys': {'country': 'US',
#          'id': 3655,
#          'sunrise': 1573480649,
#          'sunset': 1573518232,
#          'type': 1},
#  'timezone': -25200,
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 160, 'speed': 6.93}}
# {'base': 'model',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 34.56, 'lon': 76.13},
#  'dt': 1573485000,
#  'id': 1267776,
#  'main': {'grnd_level': 640,
#           'humidity': 50,
#           'pressure': 1028,
#           'sea_level': 1028,
#           'temp': 23.77,
#           'temp_max': 23.77,
#           'temp_min': 23.77},
#  'name': 'Kargil',
#  'sys': {'country': 'PK', 'sunrise': 1573435480, 'sunset': 1573473259},
#  'timezone': 19800,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 219, 'speed': 5.08}}

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
citydata=pd.DataFrame({'City':City, 'Cloudiness':Cloudiness,'Country':Country,'Date':Date,'Humidity':Humidity,
                       'Lat':Lat,'Lng':Lng,'Max Temp':Maxtemp,'Wind Speed':Winspeed })
citydata.head()
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0           Hasaki          20      JP  1573488100       100  35.73  140.83
# 1        Chavantes          85      BR  1573488337        73 -23.04  -49.71
# 2  Haines Junction          88      CA  1573488338        71  60.75 -137.51
# 3         Cherskiy         100      RU  1573488338        70  68.75  161.30
# 4   Port Elizabeth           1      US  1573488338        51  39.31  -74.98
#
#    Max Temp  Wind Speed
# 0     50.00        4.70
# 1     79.77        9.04
# 2      5.97        4.12
# 3     26.44        4.21
# 4     61.00        6.17

# %%
output_data_file = citydata.to_csv ('cities.csv', index = None, header=True)

# %%
citydata.count()
# Out:
# City          565
# Cloudiness    565
# Country       565
# Date          565
# Humidity      565
# Lat           565
# Lng           565
# Max Temp      565
# Wind Speed    565
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# import matplotlib.cm
# print(matplotlib.cm.cmap_d.keys())

# %%
plt.scatter(citydata['Lat'],citydata['Max Temp'],c=citydata['Max Temp'], cmap=plt.cm.coolwarm)
# plt.colorbar()
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
plt.title('City Latitude vs. Max Temp (11/12/19)')
plt.savefig('Latitude_vs_Max_Temp.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(citydata['Lat'],citydata['Humidity'],c=citydata['Humidity'], cmap=plt.cm.Purples)
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude vs. Humidity (11/12/19)')
plt.savefig('Latitude_vs_Humidity.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(citydata['Lat'],citydata['Cloudiness'],c=citydata['Cloudiness'],cmap=plt.cm.Blues_r)
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Latitude vs. Cloudiness (11/12/19)')
plt.savefig('Latitude_vs_Cloudiness.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(citydata['Lat'],citydata['Wind Speed'],c=citydata['Cloudiness'],cmap=plt.cm.YlOrBr)
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('City Latitude vs. Wind Speed (11/12/19)')
plt.savefig('Latitude_vs_WindSpeed.png')
